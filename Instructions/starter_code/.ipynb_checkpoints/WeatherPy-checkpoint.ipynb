# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

#if time needs to be used, we will convert time using this module
import time

# Import API key
#if it doesn't exist, a separate file named api_keys.py is imported with api_keys defined value
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# make url for requests to weather api.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL, with metric units
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
'''
with each response, 
below is the info needed for the dataframe from the json file

#name of city
print(weather_json['name'])
#cloudiness in percent
print(weather_json['clouds']['all'])
#country
print(weather_json['sys']['country'])
#date (data receiving time in UTC)
print(weather_json['dt'])
#humidity in percent
print(weather_json['main']['humidity'])
#lat, long
print(weather_json['coord']['lat'])
print(weather_json['coord']['lon'])
#max temperature in celcius
print(weather_json['main']['temp_max'])
#wind speed in meter/sec
print(weather_json['wind']['speed'])
'''

# %%
#note: this code may time out or take awhile since it is requesting a lot of cities

city_check = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = []
count = 0

#iterate through each json response, and return data into separate lists

for city in cities:
    weather_json = requests.get(query_url + city).json()
    try:
        weather_json['name']
    except KeyError:
        #if it returns a result, this keyerror wouldn't return
        print('City weather not received. Skipping to next city.')
    else:
        #count used to print out the log
        count += 1
        print(f'Receiving weather from city {count}: {city}')
        #name of city
        city_check.append(weather_json['name'])
        #cloudiness in percent
        cloudiness.append(weather_json['clouds']['all'])
        #country code
        country.append(weather_json['sys']['country'])
        #date (data receiving time in UTC)
        date.append(weather_json['dt'])
        #humidity in percent
        humidity.append(weather_json['main']['humidity'])
        #lat, long
        lat.append(weather_json['coord']['lat'])
        long.append(weather_json['coord']['lon'])
        #max temperature in celcius since in metric
        max_temp.append(weather_json['main']['temp_max'])
        #wind speed in meter/sec
        wind_speed.append(weather_json['wind']['speed'])
        
print(f'Finished Receiving {count} Cities')
# Out:
# Receiving weather from city 1: tautira
# Receiving weather from city 2: butaritari
# Receiving weather from city 3: arraial do cabo
# Receiving weather from city 4: torbay
# Receiving weather from city 5: ushuaia
# Receiving weather from city 6: tiksi
# Receiving weather from city 7: longyearbyen
# Receiving weather from city 8: rikitea
# Receiving weather from city 9: hualmay
# Receiving weather from city 10: kununurra
# Receiving weather from city 11: busselton
# Receiving weather from city 12: mataura
# Receiving weather from city 13: kaeo
# Receiving weather from city 14: sorland
# Receiving weather from city 15: hilo
# Receiving weather from city 16: urubicha
# Receiving weather from city 17: albany
# Receiving weather from city 18: chuy
# Receiving weather from city 19: port elizabeth
# Receiving weather from city 20: jamestown
# City weather not received. Skipping to next city.
# Receiving weather from city 21: hofn
# City weather not received. Skipping to next city.
# Receiving weather from city 22: sinnamary
# Receiving weather from city 23: portland
# Receiving weather from city 24: port alfred
# Receiving weather from city 25: vaini
# Receiving weather from city 26: gat
# Receiving weather from city 27: mount gambier
# City weather not received. Skipping to next city.
# Receiving weather from city 28: hithadhoo
# Receiving weather from city 29: nzerekore
# Receiving weather from city 30: codrington
# City weather not received. Skipping to next city.
# Receiving weather from city 31: mahina
# Receiving weather from city 32: qaanaaq
# Receiving weather from city 33: nuuk
# Receiving weather from city 34: castro
# Receiving weather from city 35: rabo de peixe
# Receiving weather from city 36: puerto ayora
# City weather not received. Skipping to next city.
# Receiving weather from city 37: mar del plata
# Receiving weather from city 38: atuona
# Receiving weather from city 39: marsh harbour
# Receiving weather from city 40: tuatapere
# City weather not received. Skipping to next city.
# Receiving weather from city 41: ribeira grande
# Receiving weather from city 42: mkushi
# Receiving weather from city 43: te anau
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 44: comodoro rivadavia
# Receiving weather from city 45: utrecht
# Receiving weather from city 46: drezdenko
# Receiving weather from city 47: saint-philippe
# Receiving weather from city 48: meadow lake
# Receiving weather from city 49: hobart
# Receiving weather from city 50: san carlos de bariloche
# Receiving weather from city 51: vardo
# Receiving weather from city 52: punta arenas
# City weather not received. Skipping to next city.
# Receiving weather from city 53: mayskiy
# City weather not received. Skipping to next city.
# Receiving weather from city 54: norman wells
# Receiving weather from city 55: dikson
# Receiving weather from city 56: kaitangata
# Receiving weather from city 57: auki
# Receiving weather from city 58: los llanos de aridane
# Receiving weather from city 59: ngorongoro
# Receiving weather from city 60: guerrero negro
# City weather not received. Skipping to next city.
# Receiving weather from city 61: labuhan
# Receiving weather from city 62: isangel
# Receiving weather from city 63: tigil
# Receiving weather from city 64: niamey
# Receiving weather from city 65: georgetown
# Receiving weather from city 66: kapaa
# Receiving weather from city 67: bocaiuva
# Receiving weather from city 68: la serena
# Receiving weather from city 69: yellowknife
# Receiving weather from city 70: tvoroyri
# Receiving weather from city 71: iquique
# Receiving weather from city 72: san cristobal
# City weather not received. Skipping to next city.
# Receiving weather from city 73: new norfolk
# Receiving weather from city 74: lebu
# Receiving weather from city 75: lagos
# Receiving weather from city 76: arlit
# Receiving weather from city 77: avarua
# Receiving weather from city 78: flinders
# Receiving weather from city 79: requena
# Receiving weather from city 80: airai
# Receiving weather from city 81: samarai
# City weather not received. Skipping to next city.
# Receiving weather from city 82: rio tercero
# City weather not received. Skipping to next city.
# Receiving weather from city 83: nioki
# Receiving weather from city 84: alihe
# Receiving weather from city 85: mae hong son
# City weather not received. Skipping to next city.
# Receiving weather from city 86: nova olinda do norte
# Receiving weather from city 87: esperance
# Receiving weather from city 88: bandundu
# Receiving weather from city 89: cape town
# Receiving weather from city 90: talnakh
# Receiving weather from city 91: severo-kurilsk
# Receiving weather from city 92: oussouye
# Receiving weather from city 93: weligama
# Receiving weather from city 94: dashitou
# Receiving weather from city 95: hakkari
# Receiving weather from city 96: fort nelson
# Receiving weather from city 97: dunedin
# Receiving weather from city 98: parker
# Receiving weather from city 99: lorengau
# City weather not received. Skipping to next city.
# Receiving weather from city 100: aklavik
# Receiving weather from city 101: mahebourg
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 102: port blair
# Receiving weather from city 103: viedma
# Receiving weather from city 104: hay river
# Receiving weather from city 105: bambous virieux
# Receiving weather from city 106: tirumullaivasal
# Receiving weather from city 107: bafoussam
# Receiving weather from city 108: fortuna
# Receiving weather from city 109: yenagoa
# Receiving weather from city 110: shingu
# Receiving weather from city 111: riviere-au-renard
# Receiving weather from city 112: tshikapa
# Receiving weather from city 113: nikolskoye
# Receiving weather from city 114: tevaitoa
# Receiving weather from city 115: east london
# Receiving weather from city 116: aguimes
# Receiving weather from city 117: mollendo
# Receiving weather from city 118: hermanus
# City weather not received. Skipping to next city.
# Receiving weather from city 119: muravlenko
# City weather not received. Skipping to next city.
# Receiving weather from city 120: sibolga
# Receiving weather from city 121: santiago del estero
# Receiving weather from city 122: bethel
# Receiving weather from city 123: baiyin
# Receiving weather from city 124: kavaratti
# Receiving weather from city 125: saint george
# City weather not received. Skipping to next city.
# Receiving weather from city 126: bluff
# Receiving weather from city 127: pevek
# Receiving weather from city 128: denpasar
# Receiving weather from city 129: ponta do sol
# Receiving weather from city 130: geraldton
# Receiving weather from city 131: sitka
# Receiving weather from city 132: anadyr
# Receiving weather from city 133: kodiak
# Receiving weather from city 134: bredasdorp
# Receiving weather from city 135: aykhal
# City weather not received. Skipping to next city.
# Receiving weather from city 136: khatanga
# Receiving weather from city 137: nome
# Receiving weather from city 138: iqaluit
# Receiving weather from city 139: kitob
# Receiving weather from city 140: umm kaddadah
# Receiving weather from city 141: clyde river
# Receiving weather from city 142: upernavik
# Receiving weather from city 143: palu
# Receiving weather from city 144: elat
# Receiving weather from city 145: puerto narino
# Receiving weather from city 146: tsumeb
# Receiving weather from city 147: florianopolis
# Receiving weather from city 148: avenal
# Receiving weather from city 149: coquimbo
# Receiving weather from city 150: poso
# Receiving weather from city 151: gravdal
# Receiving weather from city 152: lodja
# Receiving weather from city 153: cabo san lucas
# Receiving weather from city 154: sola
# Receiving weather from city 155: staryy nadym
# City weather not received. Skipping to next city.
# Receiving weather from city 156: zharkent
# Receiving weather from city 157: serebryansk
# Receiving weather from city 158: balaipungut
# City weather not received. Skipping to next city.
# Receiving weather from city 159: winslow
# Receiving weather from city 160: pouso alegre
# Receiving weather from city 161: ramnagar
# Receiving weather from city 162: lagoa
# Receiving weather from city 163: atar
# Receiving weather from city 164: lira
# Receiving weather from city 165: olinda
# Receiving weather from city 166: guara
# Receiving weather from city 167: kavieng
# City weather not received. Skipping to next city.
# Receiving weather from city 168: vila franca do campo
# Receiving weather from city 169: girona
# Receiving weather from city 170: mazabuka
# Receiving weather from city 171: rzhev
# Receiving weather from city 172: tarakan
# Receiving weather from city 173: tutoia
# Receiving weather from city 174: itoman
# Receiving weather from city 175: tasiilaq
# Receiving weather from city 176: mogadishu
# Receiving weather from city 177: faanui
# Receiving weather from city 178: ahipara
# Receiving weather from city 179: morrope
# City weather not received. Skipping to next city.
# Receiving weather from city 180: tavda
# Receiving weather from city 181: junction city
# Receiving weather from city 182: dangriga
# Receiving weather from city 183: taltal
# City weather not received. Skipping to next city.
# Receiving weather from city 184: provideniya
# Receiving weather from city 185: pingliang
# Receiving weather from city 186: maragogi
# Receiving weather from city 187: nanortalik
# Receiving weather from city 188: matay
# Receiving weather from city 189: naryan-mar
# Receiving weather from city 190: peniche
# Receiving weather from city 191: carnarvon
# Receiving weather from city 192: axim
# City weather not received. Skipping to next city.
# Receiving weather from city 193: vila velha
# Receiving weather from city 194: barrow
# Receiving weather from city 195: hambantota
# Receiving weather from city 196: rockland
# Receiving weather from city 197: onega
# Receiving weather from city 198: egvekinot
# Receiving weather from city 199: vanavara
# Receiving weather from city 200: yabrud
# Receiving weather from city 201: ancud
# Receiving weather from city 202: souillac
# Receiving weather from city 203: baykit
# Receiving weather from city 204: talegaon dabhade
# Receiving weather from city 205: yumen
# Receiving weather from city 206: praia da vitoria
# Receiving weather from city 207: korsakovo
# Receiving weather from city 208: dana point
# City weather not received. Skipping to next city.
# Receiving weather from city 209: port hardy
# Receiving weather from city 210: fare
# Receiving weather from city 211: saskylakh
# Receiving weather from city 212: bathsheba
# Receiving weather from city 213: roma
# Receiving weather from city 214: linxia
# Receiving weather from city 215: nakhon phanom
# Receiving weather from city 216: kirakira
# Receiving weather from city 217: san pedro
# Receiving weather from city 218: yumbe
# Receiving weather from city 219: terre-de-bas
# Receiving weather from city 220: gambela
# Receiving weather from city 221: faya
# Receiving weather from city 222: chapais
# Receiving weather from city 223: nemuro
# Receiving weather from city 224: saint simons
# Receiving weather from city 225: champerico
# Receiving weather from city 226: guadix
# Receiving weather from city 227: dingle
# Receiving weather from city 228: norfolk
# City weather not received. Skipping to next city.
# Receiving weather from city 229: deputatskiy
# Receiving weather from city 230: necochea
# Receiving weather from city 231: sao joao da barra
# Receiving weather from city 232: carauari
# Receiving weather from city 233: grindavik
# Receiving weather from city 234: la romana
# Receiving weather from city 235: amapa
# Receiving weather from city 236: sarkand
# Receiving weather from city 237: mizdah
# Receiving weather from city 238: kuandian
# Receiving weather from city 239: thompson
# Receiving weather from city 240: sao gabriel da cachoeira
# Receiving weather from city 241: sur
# Receiving weather from city 242: bloomingdale
# Receiving weather from city 243: puerto escondido
# Receiving weather from city 244: port-de-bouc
# Receiving weather from city 245: imeni poliny osipenko
# Receiving weather from city 246: tuktoyaktuk
# Receiving weather from city 247: plouzane
# Receiving weather from city 248: college
# Receiving weather from city 249: kushima
# Receiving weather from city 250: robertson
# Receiving weather from city 251: petropavlovsk-kamchatskiy
# Receiving weather from city 252: murwara
# Receiving weather from city 253: kutahya
# Receiving weather from city 254: bilibino
# Receiving weather from city 255: pisco
# Receiving weather from city 256: deori khas
# Receiving weather from city 257: pitimbu
# Receiving weather from city 258: ambulu
# Receiving weather from city 259: fairbanks
# Receiving weather from city 260: grabouw
# Receiving weather from city 261: derzhavinsk
# Receiving weather from city 262: wanaka
# Receiving weather from city 263: poquoson
# Receiving weather from city 264: floro
# City weather not received. Skipping to next city.
# Receiving weather from city 265: mandalgovi
# Receiving weather from city 266: helong
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 267: general pico
# Receiving weather from city 268: rozkishne
# Receiving weather from city 269: areka
# Receiving weather from city 270: seoul
# Receiving weather from city 271: saint-pierre
# Receiving weather from city 272: pasni
# City weather not received. Skipping to next city.
# Receiving weather from city 273: luanda
# Receiving weather from city 274: gazanjyk
# Receiving weather from city 275: shimoda
# Receiving weather from city 276: anamur
# Receiving weather from city 277: qaqortoq
# Receiving weather from city 278: mabaruma
# Receiving weather from city 279: broome
# Receiving weather from city 280: shubarkuduk
# Receiving weather from city 281: ilulissat
# Receiving weather from city 282: port keats
# Receiving weather from city 283: fukumitsu
# Receiving weather from city 284: narasannapeta
# Receiving weather from city 285: podolinec
# Receiving weather from city 286: acapulco
# Receiving weather from city 287: pangoa
# Receiving weather from city 288: dorogobuzh
# Receiving weather from city 289: pimentel
# Receiving weather from city 290: nakamura
# Receiving weather from city 291: havelock
# Receiving weather from city 292: sarankhola
# City weather not received. Skipping to next city.
# Receiving weather from city 293: dauphin
# Receiving weather from city 294: serov
# Receiving weather from city 295: novoagansk
# Receiving weather from city 296: cape coast
# Receiving weather from city 297: hienghene
# Receiving weather from city 298: sorong
# Receiving weather from city 299: yuksekova
# Receiving weather from city 300: lasa
# Receiving weather from city 301: touros
# City weather not received. Skipping to next city.
# Receiving weather from city 302: saldanha
# Receiving weather from city 303: margate
# Receiving weather from city 304: dicabisagan
# Receiving weather from city 305: san blas
# Receiving weather from city 306: virginia
# Receiving weather from city 307: nouadhibou
# City weather not received. Skipping to next city.
# Receiving weather from city 308: sal rei
# Receiving weather from city 309: shaping
# Receiving weather from city 310: san juan del sur
# Receiving weather from city 311: kaina
# Receiving weather from city 312: victoria
# Receiving weather from city 313: aberdeen
# Receiving weather from city 314: thohoyandou
# Receiving weather from city 315: moa
# Receiving weather from city 316: havre-saint-pierre
# Receiving weather from city 317: coruripe
# Receiving weather from city 318: houma
# City weather not received. Skipping to next city.
# Receiving weather from city 319: erdenet
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 320: marsa matruh
# Receiving weather from city 321: broken hill
# Receiving weather from city 322: stromness
# City weather not received. Skipping to next city.
# Receiving weather from city 323: garwa
# Receiving weather from city 324: cockburn town
# Receiving weather from city 325: mvomero
# Receiving weather from city 326: itacurubi del rosario
# Receiving weather from city 327: oranjemund
# Receiving weather from city 328: florence
# Receiving weather from city 329: abu samrah
# Receiving weather from city 330: mount isa
# Receiving weather from city 331: tazovskiy
# Receiving weather from city 332: san policarpo
# Receiving weather from city 333: coihaique
# Receiving weather from city 334: mitsamiouli
# Receiving weather from city 335: kanye
# Receiving weather from city 336: taoudenni
# Receiving weather from city 337: zwedru
# Receiving weather from city 338: san angelo
# Receiving weather from city 339: otjimbingwe
# City weather not received. Skipping to next city.
# Receiving weather from city 340: lata
# Receiving weather from city 341: bintulu
# Receiving weather from city 342: mendi
# Receiving weather from city 343: mareeba
# Receiving weather from city 344: nabire
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 345: saint anthony
# Receiving weather from city 346: chokurdakh
# Receiving weather from city 347: nyagan
# Receiving weather from city 348: alofi
# Receiving weather from city 349: el dorado
# Receiving weather from city 350: makakilo city
# Receiving weather from city 351: rock sound
# Receiving weather from city 352: along
# Receiving weather from city 353: poyarkovo
# Receiving weather from city 354: northam
# Receiving weather from city 355: vallenar
# Receiving weather from city 356: chegdomyn
# Receiving weather from city 357: ixtapa
# Receiving weather from city 358: luderitz
# Receiving weather from city 359: pizarro
# Receiving weather from city 360: lincoln
# Receiving weather from city 361: san jeronimo
# Receiving weather from city 362: waipawa
# Receiving weather from city 363: padang
# Receiving weather from city 364: puerto cabezas
# Receiving weather from city 365: kurilsk
# Receiving weather from city 366: baruun-urt
# Receiving weather from city 367: xunchang
# Receiving weather from city 368: panaba
# Receiving weather from city 369: doha
# Receiving weather from city 370: smidovich
# Receiving weather from city 371: antofagasta
# Receiving weather from city 372: rorvik
# Receiving weather from city 373: omboue
# Receiving weather from city 374: hervey bay
# City weather not received. Skipping to next city.
# Receiving weather from city 375: cabedelo
# City weather not received. Skipping to next city.
# Receiving weather from city 376: berlevag
# Receiving weather from city 377: bijawar
# Receiving weather from city 378: aksu
# Receiving weather from city 379: seymchan
# City weather not received. Skipping to next city.
# Receiving weather from city 380: haines junction
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 381: bose
# City weather not received. Skipping to next city.
# Receiving weather from city 382: vestmanna
# Receiving weather from city 383: carutapera
# City weather not received. Skipping to next city.
# Receiving weather from city 384: kargasok
# City weather not received. Skipping to next city.
# Receiving weather from city 385: gizo
# City weather not received. Skipping to next city.
# Receiving weather from city 386: bukama
# Receiving weather from city 387: zhezkazgan
# City weather not received. Skipping to next city.
# Receiving weather from city 388: hobyo
# Receiving weather from city 389: marquette
# Receiving weather from city 390: henties bay
# Receiving weather from city 391: samfya
# Receiving weather from city 392: apollonia
# City weather not received. Skipping to next city.
# Receiving weather from city 393: walvis bay
# Receiving weather from city 394: vao
# Receiving weather from city 395: yeniseysk
# Receiving weather from city 396: luan
# Receiving weather from city 397: nicoya
# Receiving weather from city 398: mawlaik
# City weather not received. Skipping to next city.
# Receiving weather from city 399: shunyi
# Receiving weather from city 400: atkinson
# Receiving weather from city 401: pangnirtung
# Receiving weather from city 402: mookane
# Receiving weather from city 403: ribeira do pombal
# Receiving weather from city 404: shinuhayr
# Receiving weather from city 405: benguela
# City weather not received. Skipping to next city.
# Receiving weather from city 406: gambo
# Receiving weather from city 407: grand gaube
# Receiving weather from city 408: westport
# Receiving weather from city 409: challakere
# City weather not received. Skipping to next city.
# Receiving weather from city 410: foam lake
# Receiving weather from city 411: warrington
# Receiving weather from city 412: richards bay
# Receiving weather from city 413: yevlax
# Receiving weather from city 414: beysehir
# Receiving weather from city 415: ponta pora
# Receiving weather from city 416: riberalta
# Receiving weather from city 417: turtas
# City weather not received. Skipping to next city.
# Receiving weather from city 418: mayumba
# City weather not received. Skipping to next city.
# Receiving weather from city 419: kaitong
# Receiving weather from city 420: whitehorse
# Receiving weather from city 421: velikodvorskiy
# Receiving weather from city 422: paka
# Receiving weather from city 423: lyaskelya
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 424: san vicente
# Receiving weather from city 425: fenoarivo
# Receiving weather from city 426: kang
# Receiving weather from city 427: olbia
# Receiving weather from city 428: sigli
# Receiving weather from city 429: extrema
# Receiving weather from city 430: galesong
# Receiving weather from city 431: riyadh
# Receiving weather from city 432: ileza
# Receiving weather from city 433: hunchun
# Receiving weather from city 434: bod
# Receiving weather from city 435: kichera
# Receiving weather from city 436: bubaque
# Receiving weather from city 437: beloha
# Receiving weather from city 438: narsaq
# Receiving weather from city 439: port moresby
# City weather not received. Skipping to next city.
# Receiving weather from city 440: khor
# Receiving weather from city 441: poum
# Receiving weather from city 442: hanstholm
# Receiving weather from city 443: inhambane
# Receiving weather from city 444: la ronge
# Receiving weather from city 445: gamba
# Receiving weather from city 446: cap malheureux
# Receiving weather from city 447: salcea
# Receiving weather from city 448: kyenjojo
# Receiving weather from city 449: hammerfest
# Receiving weather from city 450: rensvik
# Receiving weather from city 451: rawson
# Receiving weather from city 452: chuzhou
# Receiving weather from city 453: karratha
# Receiving weather from city 454: evensk
# Receiving weather from city 455: sao filipe
# Receiving weather from city 456: novyy urengoy
# Receiving weather from city 457: worthington
# Receiving weather from city 458: snezhnogorsk
# Receiving weather from city 459: leshukonskoye
# Receiving weather from city 460: laguna
# Receiving weather from city 461: panguna
# Receiving weather from city 462: waingapu
# Receiving weather from city 463: krasnoturansk
# Receiving weather from city 464: jerusalen
# Receiving weather from city 465: adrar
# Receiving weather from city 466: soe
# Receiving weather from city 467: mbarara
# Receiving weather from city 468: hasaki
# Receiving weather from city 469: killybegs
# Receiving weather from city 470: port macquarie
# Receiving weather from city 471: the pas
# Receiving weather from city 472: batamshinskiy
# City weather not received. Skipping to next city.
# Receiving weather from city 473: itoigawa
# Receiving weather from city 474: beyneu
# Receiving weather from city 475: siniscola
# Receiving weather from city 476: castrillon
# Receiving weather from city 477: khasan
# Receiving weather from city 478: montepuez
# Receiving weather from city 479: hami
# Receiving weather from city 480: klaksvik
# Receiving weather from city 481: san felipe
# Receiving weather from city 482: kipushi
# Receiving weather from city 483: alice springs
# Receiving weather from city 484: pultusk
# Receiving weather from city 485: farcasa
# Receiving weather from city 486: ayan
# Receiving weather from city 487: itaituba
# Receiving weather from city 488: lucapa
# Receiving weather from city 489: komsomolskiy
# Receiving weather from city 490: sabha
# Receiving weather from city 491: tarko-sale
# Receiving weather from city 492: kota kinabalu
# Receiving weather from city 493: velingara
# Receiving weather from city 494: rosice
# Receiving weather from city 495: karpathos
# Receiving weather from city 496: paita
# Receiving weather from city 497: viseu
# Receiving weather from city 498: cheb
# Receiving weather from city 499: caravelas
# Receiving weather from city 500: yeppoon
# Receiving weather from city 501: bajram curri
# Receiving weather from city 502: kudahuvadhoo
# Receiving weather from city 503: kutum
# Receiving weather from city 504: saint andrews
# Receiving weather from city 505: rio grande
# Receiving weather from city 506: santa cruz
# Receiving weather from city 507: mindelo
# Receiving weather from city 508: kenai
# Receiving weather from city 509: sindor
# Receiving weather from city 510: kalmunai
# Receiving weather from city 511: nouakchott
# City weather not received. Skipping to next city.
# City weather not received. Skipping to next city.
# Receiving weather from city 512: masaka
# Receiving weather from city 513: fethiye
# Receiving weather from city 514: bloomington
# Receiving weather from city 515: quixere
# Receiving weather from city 516: gao
# City weather not received. Skipping to next city.
# Receiving weather from city 517: zambezi
# Receiving weather from city 518: ouadda
# Receiving weather from city 519: kungurtug
# Receiving weather from city 520: los zacatones
# Receiving weather from city 521: takoradi
# Receiving weather from city 522: honiara
# Receiving weather from city 523: hokitika
# Receiving weather from city 524: cascais
# Receiving weather from city 525: bambanglipuro
# Receiving weather from city 526: mercedes
# Receiving weather from city 527: palana
# Receiving weather from city 528: muros
# City weather not received. Skipping to next city.
# Receiving weather from city 529: mayo
# Receiving weather from city 530: tianpeng
# Receiving weather from city 531: soyo
# Receiving weather from city 532: likasi
# Receiving weather from city 533: ust-nera
# Receiving weather from city 534: lazaro cardenas
# Receiving weather from city 535: conceicao do araguaia
# Receiving weather from city 536: moree
# Receiving weather from city 537: mantua
# Receiving weather from city 538: harper
# Receiving weather from city 539: milkovo
# Receiving weather from city 540: quatre cocos
# Receiving weather from city 541: tabou
# Receiving weather from city 542: kidal
# Receiving weather from city 543: kozhva
# Receiving weather from city 544: goderich
# Receiving weather from city 545: chynadiyovo
# Receiving weather from city 546: machinga
# Receiving weather from city 547: tessalit
# Receiving weather from city 548: xuanhua
# Receiving weather from city 549: orlik
# City weather not received. Skipping to next city.
# Receiving weather from city 550: dengzhou
# Receiving weather from city 551: mehamn
# Receiving weather from city 552: kasempa
# Receiving weather from city 553: kimbe
# Receiving weather from city 554: davila

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_received = {
    "city": city_check,
    "cloudiness": cloudiness,
    "country": country,
    "date": date,
    "humidity": humidity,
    "lat": lat,
    "lng": long,
    "max temp": max_temp,
    "wind speed": wind_speed
}

weather_data = pd.DataFrame(weather_received)
weather_data.to_csv(f'../{output_data_file}', index=False)
weather_data.count()
#from here, the new output file will be used for data plotting
# Out:
# city          554
# cloudiness    554
# country       554
# date          554
# humidity      554
# lat           554
# lng           554
# max temp      554
# wind speed    554
# dtype: int64

# %%
#using output data file for data plotting
weather_data1 = pd.read_csv(f'../{output_data_file}')
weather_data1.head()
# Out:
#               city  cloudiness country        date  humidity    lat     lng  \
# 0          Tautira          40      PF  1553633248        62 -17.73 -149.15
# 1       Butaritari          48      KI  1553633386       100   3.07  172.79
# 2  Arraial do Cabo          20      BR  1553630400        61 -22.97  -42.02
# 3           Torbay          90      CA  1553633385        58  47.66  -52.73
# 4          Ushuaia          75      AR  1553630400        62 -54.81  -68.31
#
#    max temp  wind speed
# 0     31.00        1.50
# 1     28.54        7.26
# 2     28.00        6.20
# 3     -2.22        5.70
# 4     12.00        3.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
#convert all data from celcius to fahrenheit
weather_data1["max temp"] = weather_data1["max temp"] *(9/5) + 32
plt.scatter(weather_data1["lat"], weather_data1["max temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitiude vs. Max Temp in Random World Cities")
plt.ylabel("Max Temp (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_max_temp_cities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#checking to see if there is an outlier for humidity data
weather_data1.sort_values(by=['humidity'], ascending=False).head()

#in this data, Paita has a humidity of 290, which isn't possible
#this will be ignored in the scatter plot with humidity
# Out:
#            city  cloudiness country        date  humidity    lat     lng  \
# 495       Paita           0      PE  1553630400       290  -5.09  -81.11
# 171     Tarakan          76      ID  1553633703       100   3.30  117.63
# 186  Nanortalik          64      GL  1553633782       100  60.14  -45.24
# 498   Caravelas           0      BR  1553633885       100 -17.73  -39.27
# 109      Shingu           0      JP  1553633757       100  33.72  135.99
#
#      max temp  wind speed
# 495     17.00        4.41
# 171     26.04        1.01
# 186     -4.07       12.21
# 498     27.99        4.41
# 109     11.79        3.76

# %%
# Build a scatter plot
plt.scatter(weather_data1["lat"], weather_data1["humidity"], marker="o", edgecolors="black")

# graph labels
plt.title("Latitiude vs. Humidity in Random World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
#limit the y axis so it ignores any points past 100 humidity
plt.ylim(0, 105)

# Save the figure
plt.savefig("../output_data/humidity_in_cities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot 
plt.scatter(weather_data1["lat"], weather_data1["cloudiness"], marker="o", edgecolors="black")

# graph labels
plt.title("Latitiude vs. Cloudiness in Random World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Cloudiness_vs_temp_world_cites.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
#convert windspeed from meters/sec to mph
weather_data1["wind speed"] = weather_data1["wind speed"] * 2.237
plt.scatter(weather_data1["lat"], weather_data1["wind speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("Latitiude vs. Wind Speed in Random World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("latitude_vs_windspeed_cities.png")

# Show plot
plt.show()

# %%
'''
what is the weather like as we approach the equator?
Based on the graphs
Max temperature is higher.
Humidity is about the same, with a slightly larger cluster by the equator.
Wind Speed is also about the same as humidity in its clustering.

'''
